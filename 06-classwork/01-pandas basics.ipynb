# %% [markdown]
# # Pandas basics

# %%
# !ls

#! allows you to run command line commands in Jupyter
# Out:
# 01-pandas basics.ipynb continent_facts.csv    countries.csv

# %%
# !pip install --verbose pandas
# Out:
# Using pip 24.0 from /Users/T/.pyenv/versions/3.11.8/lib/python3.11/site-packages/pip (python 3.11)
# ...

# %%
import requests

# %%
#THIS IS APPARETLY VERY BAD

#import pandas
#countries = pandas.read_csv("countries.csv")
#countries

# %%
import pandas as pd

# %%
df = pd.read_csv("countries.csv")
df.tail() # last 5
df.head() # first 5
# Out:
#                country   continent  life_expectancy  population           gdp
# 0          Afghanistan        Asia           54.863    22856302   15153728226
# 1              Albania      Europe           74.200     3071856   12886435920
# 2              Algeria      Africa           68.963    30533827  155661450046
# 3               Angola      Africa           45.234    13926373   34063908358
# 4  Antigua and Barbuda  N. America           73.544       77656     989182128

# %%
df['country'] #display only one column
df.loc[88] #display only one row (by index only)
df[df['continent'] == 'Asia'] # search by a specific parameter
df[(df['continent'] == 'Asia') & (df['life_expectancy'] > 75)] #search by multiple parameters
# Out:
#               country continent  life_expectancy  population            gdp
# 23             Brunei      Asia           75.927      327036    15704268720
# 72   Hong Kong, China      Asia           80.361     6783317   203309577124
# 80             Israel      Asia           78.750     6014953   137345436802
# 83              Japan      Asia           81.350   125720310  3590446333290
# 89        Korea, Rep.      Asia           76.114    45987624   781559669880
# 100      Macao, China      Asia           77.627      431867     9722189904
# 135             Qatar      Asia           76.680      590957    35690257058
# 148         Singapore      Asia           78.340     3919300   144363496200
# 163            Taiwan      Asia           76.020    22183000   521855075000

# %%
#sort data frame by a certain data set
df.sort_values('life_expectancy', ascending = False) #shift+tab gives documentation of commands apparently
# .sort changes it permanently
#sorted() just displays it and leaves df unchanged unless you save it seperately
# Out:
#                   country continent  life_expectancy  population  \
# 83                  Japan      Asia           81.350   125720310
# 72       Hong Kong, China      Asia           80.361     6783317
# 161           Switzerland    Europe           79.990     7167908
# 7               Australia   Oceania           79.930    19164351
# 160                Sweden    Europe           79.840     8860153
# ..                    ...       ...              ...         ...
# 3                  Angola    Africa           45.234    13926373
# 187              Zimbabwe    Africa           43.976    12509477
# 31   Central African Rep.    Africa           43.727     3701607
# 186                Zambia    Africa           41.802    10201562
# 147          Sierra Leone    Africa           38.123     4143115
#
#                gdp
# 83   3590446333290
# 72    203309577124
# 161   246475684488
# 7     560384787591
# 160   253754781920
# ..             ...
# 3      34063908358
# 187     9319560365
# ...

# %%
df['gdp'].describe() #gives you information on a column
# Out:
# count    1.880000e+02
# mean     2.570011e+11
# std      9.630380e+11
# min      1.861332e+08
# 25%      7.610312e+09
# 50%      2.499126e+10
# 75%      1.457142e+11
# max      1.123149e+13
# Name: gdp, dtype: float64

# %%
df[['gdp', 'per_capita']].corr() #correlation
# Out:
#                  gdp  per_capita
# gdp         1.000000    0.998864
# per_capita  0.998864    1.000000

# %%
df['per_capita'] = df['gdp']/df['life_expectancy'] # add a new column using a formula
df
# Out:
#                  country   continent  life_expectancy  population  \
# 0            Afghanistan        Asia           54.863    22856302
# 1                Albania      Europe           74.200     3071856
# 2                Algeria      Africa           68.963    30533827
# 3                 Angola      Africa           45.234    13926373
# 4    Antigua and Barbuda  N. America           73.544       77656
# ..                   ...         ...              ...         ...
# 183              Vietnam        Asia           73.777    78758010
# 184   West Bank and Gaza        Asia           70.929     3198560
# 185          Yemen, Rep.        Asia           60.404    17723186
# 186               Zambia      Africa           41.802    10201562
# 187             Zimbabwe      Africa           43.976    12509477
#
#               gdp    per_capita
# 0     15153728226  2.762103e+08
# 1     12886435920  1.736716e+08
# 2    155661450046  2.257173e+09
# 3     34063908358  7.530598e+08
# ...

# %%
South_America_df = df[df['continent'] == 'S. America'] #make a new data frame
#South_America_df['population'] = 0 # alternate universe that doesn't affect total df ACTUALLY THIS DOESNT WORK I MISSED THE NOTES

df['continent'].value_counts() #tallies data per fitting requirements
# Out:
# continent
# Africa        54
# Asia          48
# Europe        42
# N. America    22
# S. America    12
# Oceania       10
# Name: count, dtype: int64

# %%
url = "https://www.theguardian.com/football/laligafootball/table" #GET A TABLE FROM THE INTERNET
df_new = pd.read_html(url)
len(df_new) #how many tables on this site (important if number =/= 1)
# Out:
# 1

# %%
url = "https://www.basketball-reference.com/players/o/onealsh01.html" #GET A TABLE FROM THE INTERNET
df_2 = pd.read_html(url)
df_2[0]
# Out:
#        Season   Age   Tm   Lg  Pos       G      GS    MP    FG   FGA  ...  \
# 0     1992-93  20.0  ORL  NBA    C    81.0    81.0  37.9   9.0  16.1  ...
# 1     1993-94  21.0  ORL  NBA    C    81.0    81.0  39.8  11.8  19.6  ...
# 2     1994-95  22.0  ORL  NBA    C    79.0    79.0  37.0  11.8  20.2  ...
# 3     1995-96  23.0  ORL  NBA    C    54.0    52.0  36.0  11.0  19.1  ...
# 4     1996-97  24.0  LAL  NBA    C    51.0    51.0  38.1  10.8  19.4  ...
# 5     1997-98  25.0  LAL  NBA    C    60.0    57.0  36.3  11.2  19.1  ...
# 6     1998-99  26.0  LAL  NBA    C    49.0    49.0  34.8  10.4  18.1  ...
# 7     1999-00  27.0  LAL  NBA    C    79.0    79.0  40.0  12.1  21.1  ...
# 8     2000-01  28.0  LAL  NBA    C    74.0    74.0  39.5  11.0  19.2  ...
# 9     2001-02  29.0  LAL  NBA    C    67.0    66.0  36.1  10.6  18.3  ...
# 10    2002-03  30.0  LAL  NBA    C    67.0    66.0  37.8  10.4  18.1  ...
# 11    2003-04  31.0  LAL  NBA    C    67.0    67.0  36.8   8.3  14.1  ...
# ...

# %%
df_new[0].to_csv("Team.csv", index = False) #write data frame to csv, removes index

# %%
pd.read_csv("Team.csv")
# Out:
#      P            Team  GP   W   D   L   F   A  GD  Pts  \
# 0    1     Real Madrid  38  29   8   1  87  26  61   95
# 1    2       Barcelona  38  26   7   5  79  44  35   85
# 2    3          Girona  38  25   6   7  85  46  39   81
# 3    4        Atlético  38  24   4  10  70  43  27   76
# 4    5        A Bilbao  38  19  11   8  61  37  24   68
# 5    6   Real Sociedad  38  16  12  10  51  39  12   60
# 6    7      Real Betis  38  14  15   9  48  45   3   57
# 7    8      Villarreal  38  14  11  13  65  65   0   53
# 8    9        Valencia  38  13  10  15  40  45  -5   49
# 9   10          Alaves  38  12  10  16  36  46 -10   46
# 10  11         Osasuna  38  12   9  17  45  56 -11   45
# 11  12          Getafe  38  10  13  15  42  54 -12   43
# 12  13      Celta Vigo  38  10  11  17  46  57 -11   41
# 13  14         Sevilla  38  10  11  17  48  54  -6   41
# 14  15        Mallorca  38   8  16  14  33  44 -11   40
# 15  16      Las Palmas  38  10  10  18  33  47 -14   40
# ...

# %%
pd.json_normalize(data[column 1][column 2]) #make a pandas data frame out of api data so you can save it
