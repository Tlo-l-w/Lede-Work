# %%
import requests


address = "2950%20Broadway%20New%20York%20NY"
api_key = "AIzaSyC6Xu4GUeKWFYXLm9GRBAnGkbVClo9HD_o"

# %%
url = f"https://maps.googleapis.com/maps/api/geocode/json?address={address}&key={api_key}"
print(url)

response = requests.get(url)
data = response.json
# Out:
# https://maps.googleapis.com/maps/api/geocode/json?address=2950%20Broadway%20New%20York%20NY&key=AIzaSyC6Xu4GUeKWFYXLm9GRBAnGkbVClo9HD_o

# %%
print(data['results'])
## HOW DO I CALL PARTS OF A JSON FILE
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 print(data['results'])
#       2 ## HOW DO I CALL PARTS OF A JSON FILE
#
# KeyError: 'results'

# %%
import geocoder

api_key = "AIzaSyC6Xu4GUeKWFYXLm9GRBAnGkbVClo9HD_o"
g = geocoder.google('2950 Broadway, New York, NY', key=api_key)
g.latlng
# Out:
# [40.8076284, -73.963656]

# %%
# !pip install geocoder

# %%
#Pagination APIs
#Total results vs Per page results

#while loop
#manually pick number of pages

#list slicing to avoid crashing shit

#import time, time.sleep to add delay

# %%
response = requests.get("https://pokeapi.co/api/v2/type/electric")
data = response.json()
data.keys()

for pokemon in data['pokemon']:
    print(pokemon['pokemon']['name'])
    print("________________")
# Out:
# pikachu
# ________________
# raichu
# ________________
# magnemite
# ________________
# magneton
# ________________
# voltorb
# ________________
# electrode
# ________________
# electabuzz
# ________________
# jolteon
# ________________
# zapdos
# ________________
# chinchou
# ________________
# lanturn
# ________________
# pichu
# ________________
# mareep
# ________________
# flaaffy
# ________________
# ampharos
# ________________
# elekid
# ________________
# raikou
# ________________
# electrike
# ________________
# manectric
# ________________
# plusle
# ________________
# minun
# ________________
# shinx
# ________________
# luxio
# ________________
# luxray
# ________________
# pachirisu
# ________________
# magnezone
# ________________
# electivire
# ________________
# rotom
# ________________
# blitzle
# ________________
# zebstrika
# ________________
# emolga
# ________________
# joltik
# ________________
# galvantula
# ________________
# tynamo
# ________________
# ...

# %%
response = requests.get("https://pokeapi.co/api/v2/type/electric")
data = response.json()
data.keys()


for language in data['names']:
    print("_____________")
    if language['language']['name'] == 'ko':
        print(language['name'])
# Out:
# _____________
# _____________
# 전기
# _____________
# _____________
# _____________
# _____________
# _____________
# _____________
# _____________
# _____________
